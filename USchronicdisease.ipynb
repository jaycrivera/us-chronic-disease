# %%
# Essential libraries
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical computations

# Data visualization
import matplotlib.pyplot as plt  # Basic plotting
import seaborn as sns  # Statistical data visualization

# Display settings for Pandas
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.float_format', '{:.2f}'.format)  # Format floats

# Ignore warnings (optional)
import warnings
warnings.filterwarnings('ignore')

# Load the dataset (modify the filename accordingly)
df = pd.read_csv("U.S._Chronic_Disease_Indicators.csv")

# Quick check of the dataset
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource     Topic  \
# 0       2019     2019           AR     Arkansas      BRFSS  Diabetes
# 1       2019     2019           ID        Idaho      BRFSS  Diabetes
# 2       2019     2019           IN      Indiana      YRBSS     Sleep
# 3       2019     2019           IA         Iowa       NVSS    Asthma
# 4       2019     2019           IA         Iowa      BRFSS    Asthma
#
#                                             Question  Response DataValueUnit  \
# 0                              Diabetes among adults       NaN             %
# 1                              Diabetes among adults       NaN             %
# 2    Short sleep duration among high school students       NaN             %
# 3  Asthma mortality among all people, underlying ...       NaN        Number
# 4                        Current asthma among adults       NaN             %
#
#       DataValueType  DataValue  DataValueAlt DataValueFootnoteSymbol  \
# ...

# %%
df = pd.read_csv('U.S._Chronic_Disease_Indicators.csv')

# %%
df.tail()
# Out:
#         YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 309210       2022     2022           VI  Virgin Islands      BRFSS
# 309211       2022     2022           WV   West Virginia      BRFSS
# 309212       2022     2022           WI       Wisconsin      BRFSS
# 309213       2022     2022           VT         Vermont      BRFSS
# 309214       2022     2022           WA      Washington      BRFSS
#
#                                         Topic  \
# 309210                                Tobacco
# 309211  Chronic Obstructive Pulmonary Disease
# 309212                           Immunization
# 309213          Social Determinants of Health
# 309214                                Alcohol
#
#                                                  Question  Response  \
# 309210  Quit attempts in the past year among adult cur...       NaN
# 309211  Chronic obstructive pulmonary disease among ad...       NaN
# 309212  Pneumococcal vaccination among adults aged 65 ...       NaN
# ...

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource     Topic  \
# 0       2019     2019           AR     Arkansas      BRFSS  Diabetes
# 1       2019     2019           ID        Idaho      BRFSS  Diabetes
# 2       2019     2019           IN      Indiana      YRBSS     Sleep
# 3       2019     2019           IA         Iowa       NVSS    Asthma
# 4       2019     2019           IA         Iowa      BRFSS    Asthma
#
#                                             Question  Response DataValueUnit  \
# 0                              Diabetes among adults       NaN             %
# 1                              Diabetes among adults       NaN             %
# 2    Short sleep duration among high school students       NaN             %
# 3  Asthma mortality among all people, underlying ...       NaN        Number
# 4                        Current asthma among adults       NaN             %
#
#       DataValueType  DataValue  DataValueAlt DataValueFootnoteSymbol  \
# ...

# %%
df.shape
# Out:
# (309215, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309215 entries, 0 to 309214
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  309215 non-null  int64
#  1   YearEnd                    309215 non-null  int64
#  2   LocationAbbr               309215 non-null  object
#  3   LocationDesc               309215 non-null  object
#  4   DataSource                 309215 non-null  object
#  5   Topic                      309215 non-null  object
#  6   Question                   309215 non-null  object
#  7   Response                   0 non-null       float64
#  8   DataValueUnit              309215 non-null  object
#  9   DataValueType              309215 non-null  object
#  10  DataValue                  209196 non-null  float64
#  11  DataValueAlt               209196 non-null  float64
#  12  DataValueFootnoteSymbol    101716 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# DataSource                        0
# Topic                             0
# Question                          0
# Response                     309215
# DataValueUnit                     0
# DataValueType                     0
# DataValue                    100019
# DataValueAlt                 100019
# DataValueFootnoteSymbol      207499
# DataValueFootnote            207499
# LowConfidenceLimit           120330
# HighConfidenceLimit          120325
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2      309215
# Stratification2              309215
# StratificationCategory3      309215
# Stratification3              309215
# Geolocation                    5763
# LocationID                        0
# TopicID                           0
# QuestionID                        0
# ...

# %%
df = pd.read_csv("U.S._Chronic_Disease_Indicators.csv")  # Reload from the source file

# %%
df_original = df.copy()

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# DataSource                        0
# Topic                             0
# Question                          0
# Response                     309215
# DataValueUnit                     0
# DataValueType                     0
# DataValue                    100019
# DataValueAlt                 100019
# DataValueFootnoteSymbol      207499
# DataValueFootnote            207499
# LowConfidenceLimit           120330
# HighConfidenceLimit          120325
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2      309215
# Stratification2              309215
# StratificationCategory3      309215
# Stratification3              309215
# Geolocation                    5763
# LocationID                        0
# TopicID                           0
# QuestionID                        0
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# YearStart                     0.00
# YearEnd                       0.00
# LocationAbbr                  0.00
# LocationDesc                  0.00
# DataSource                    0.00
# Topic                         0.00
# Question                      0.00
# Response                    100.00
# DataValueUnit                 0.00
# DataValueType                 0.00
# DataValue                    32.35
# DataValueAlt                 32.35
# DataValueFootnoteSymbol      67.11
# DataValueFootnote            67.11
# LowConfidenceLimit           38.91
# HighConfidenceLimit          38.91
# StratificationCategory1       0.00
# Stratification1               0.00
# StratificationCategory2     100.00
# Stratification2             100.00
# StratificationCategory3     100.00
# Stratification3             100.00
# Geolocation                   1.86
# LocationID                    0.00
# TopicID                       0.00
# QuestionID                    0.00
# ResponseID                  100.00
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame
columns_to_drop = [
    "Response", "StratificationCategory2", "Stratification2", 
    "StratificationCategory3", "Stratification3", "ResponseID", 
    "StratificationCategoryID2", "StratificationID2", 
    "StratificationCategoryID3", "StratificationID3"
]

# Drop the specified columns
df_cleaned = df.drop(columns=columns_to_drop)

# Print the remaining columns to verify
print("Remaining columns after dropping:\n", df_cleaned.columns)

# Print the cleaned DataFrame
print("\nCleaned DataFrame:\n", df_cleaned)
# Out:
# Remaining columns after dropping:
#  Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DataValueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'Geolocation', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')
#
# Cleaned DataFrame:
#          YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0            2019     2019           AR        Arkansas      BRFSS
# 1            2019     2019           ID           Idaho      BRFSS
# 2            2019     2019           IN         Indiana      YRBSS
# 3            2019     2019           IA            Iowa       NVSS
# 4            2019     2019           IA            Iowa      BRFSS
# ...

# %%
# Define the exact columns to drop
columns_to_drop = [
    "Response", "StratificationCategory2", "Stratification2", 
    "StratificationCategory3", "Stratification3", "ResponseID", 
    "StratificationCategoryID2", "StratificationID2", 
    "StratificationCategoryID3", "StratificationID3"
]

# Ensure column names are stripped of spaces
df.columns = df.columns.str.strip()

# Drop columns if they exist in the DataFrame
df_cleaned = df.drop(columns=[col for col in columns_to_drop if col in df.columns])

# Print the remaining columns to confirm
print("Remaining columns after dropping:\n", df_cleaned.columns)
# Out:
# Remaining columns after dropping:
#  Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DataValueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'Geolocation', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
print(df_cleaned.columns)
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DataValueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'Geolocation', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
for col in columns_to_drop:
    assert col not in df_cleaned.columns, f"Column {col} was not dropped!"
print("All specified columns were successfully dropped! ✅")
# Out:
# All specified columns were successfully dropped! ✅

# %%
missing_columns = set(columns_to_drop) - set(df_cleaned.columns)
print("Dropped columns:", missing_columns)
# Out:
# Dropped columns: {'StratificationCategory2', 'StratificationID2', 'Stratification2', 'StratificationCategoryID2', 'StratificationID3', 'StratificationCategoryID3', 'Response', 'Stratification3', 'ResponseID', 'StratificationCategory3'}

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# YearStart                     0.00
# YearEnd                       0.00
# LocationAbbr                  0.00
# LocationDesc                  0.00
# DataSource                    0.00
# Topic                         0.00
# Question                      0.00
# Response                    100.00
# DataValueUnit                 0.00
# DataValueType                 0.00
# DataValue                    32.35
# DataValueAlt                 32.35
# DataValueFootnoteSymbol      67.11
# DataValueFootnote            67.11
# LowConfidenceLimit           38.91
# HighConfidenceLimit          38.91
# StratificationCategory1       0.00
# Stratification1               0.00
# StratificationCategory2     100.00
# Stratification2             100.00
# StratificationCategory3     100.00
# Stratification3             100.00
# Geolocation                   1.86
# LocationID                    0.00
# TopicID                       0.00
# QuestionID                    0.00
# ResponseID                  100.00
# ...

# %%
df_cleaned = df.drop(columns=columns_to_drop)

# %%
print(df_cleaned.columns)
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DataValueFootnoteSymbol', 'DataValueFootnote',
#        'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory1',
#        'Stratification1', 'Geolocation', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# YearStart                     0.00
# YearEnd                       0.00
# LocationAbbr                  0.00
# LocationDesc                  0.00
# DataSource                    0.00
# Topic                         0.00
# Question                      0.00
# Response                    100.00
# DataValueUnit                 0.00
# DataValueType                 0.00
# DataValue                    32.35
# DataValueAlt                 32.35
# DataValueFootnoteSymbol      67.11
# DataValueFootnote            67.11
# LowConfidenceLimit           38.91
# HighConfidenceLimit          38.91
# StratificationCategory1       0.00
# Stratification1               0.00
# StratificationCategory2     100.00
# Stratification2             100.00
# StratificationCategory3     100.00
# Stratification3             100.00
# Geolocation                   1.86
# LocationID                    0.00
# TopicID                       0.00
# QuestionID                    0.00
# ResponseID                  100.00
# ...

# %%
df_cleaned.isnull().sum() / df_cleaned.shape[0] * 100
# Out:
# YearStart                    0.00
# YearEnd                      0.00
# LocationAbbr                 0.00
# LocationDesc                 0.00
# DataSource                   0.00
# Topic                        0.00
# Question                     0.00
# DataValueUnit                0.00
# DataValueType                0.00
# DataValue                   32.35
# DataValueAlt                32.35
# DataValueFootnoteSymbol     67.11
# DataValueFootnote           67.11
# LowConfidenceLimit          38.91
# HighConfidenceLimit         38.91
# StratificationCategory1      0.00
# Stratification1              0.00
# Geolocation                  1.86
# LocationID                   0.00
# TopicID                      0.00
# QuestionID                   0.00
# DataValueTypeID              0.00
# StratificationCategoryID1    0.00
# StratificationID1            0.00
# dtype: float64

# %%
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# YearStart                    0.00
# YearEnd                      0.00
# LocationAbbr                 0.00
# LocationDesc                 0.00
# DataSource                   0.00
# Topic                        0.00
# Question                     0.00
# DataValueUnit                0.00
# DataValueType                0.00
# DataValue                   32.35
# DataValueAlt                32.35
# DataValueFootnoteSymbol     67.11
# DataValueFootnote           67.11
# LowConfidenceLimit          38.91
# HighConfidenceLimit         38.91
# StratificationCategory1      0.00
# Stratification1              0.00
# Geolocation                  1.86
# LocationID                   0.00
# TopicID                      0.00
# QuestionID                   0.00
# DataValueTypeID              0.00
# StratificationCategoryID1    0.00
# StratificationID1            0.00
# dtype: float64

# %%
df.drop(columns=['DataValueFootnoteSymbol', 'DataValueFootnote'], inplace=True)

# %%
print(df.columns)
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'Geolocation',
#        'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID',
#        'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# YearStart                    0.00
# YearEnd                      0.00
# LocationAbbr                 0.00
# LocationDesc                 0.00
# DataSource                   0.00
# Topic                        0.00
# Question                     0.00
# DataValueUnit                0.00
# DataValueType                0.00
# DataValue                   32.35
# DataValueAlt                32.35
# LowConfidenceLimit          38.91
# HighConfidenceLimit         38.91
# StratificationCategory1      0.00
# Stratification1              0.00
# Geolocation                  1.86
# LocationID                   0.00
# TopicID                      0.00
# QuestionID                   0.00
# DataValueTypeID              0.00
# StratificationCategoryID1    0.00
# StratificationID1            0.00
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309215 entries, 0 to 309214
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  309215 non-null  int64
#  1   YearEnd                    309215 non-null  int64
#  2   LocationAbbr               309215 non-null  object
#  3   LocationDesc               309215 non-null  object
#  4   DataSource                 309215 non-null  object
#  5   Topic                      309215 non-null  object
#  6   Question                   309215 non-null  object
#  7   DataValueUnit              309215 non-null  object
#  8   DataValueType              309215 non-null  object
#  9   DataValue                  209196 non-null  float64
#  10  DataValueAlt               209196 non-null  float64
#  11  LowConfidenceLimit         188885 non-null  float64
#  12  HighConfidenceLimit        188890 non-null  float64
# ...

# %%
df.shape
# Out:
# (309215, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309215 entries, 0 to 309214
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  309215 non-null  int64
#  1   YearEnd                    309215 non-null  int64
#  2   LocationAbbr               309215 non-null  object
#  3   LocationDesc               309215 non-null  object
#  4   DataSource                 309215 non-null  object
#  5   Topic                      309215 non-null  object
#  6   Question                   309215 non-null  object
#  7   DataValueUnit              309215 non-null  object
#  8   DataValueType              309215 non-null  object
#  9   DataValue                  209196 non-null  float64
#  10  DataValueAlt               209196 non-null  float64
#  11  LowConfidenceLimit         188885 non-null  float64
#  12  HighConfidenceLimit        188890 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print('*' * 10)
# Out:
# LocationAbbr
# US    5763
# TN    5750
# AL    5748
# VT    5748
# PA    5748
# UT    5748
# VA    5748
# WI    5748
# WY    5748
# AR    5748
# OR    5748
# GA    5748
# HI    5748
# CO    5748
# CT    5748
# IL    5748
# DC    5748
# WA    5748
# DE    5748
# ME    5748
# MO    5748
# NY    5748
# KS    5748
# LA    5748
# MI    5748
# MN    5748
# MS    5748
# NE    5748
# NJ    5748
# MA    5748
# ND    5748
# MT    5742
# NM    5740
# SD    5740
# FL    5699
# NH    5699
# WV    5699
# IA    5699
# KY    5699
# MD    5699
# AK    5691
# OK    5650
# RI    5650
# NC    5650
# AZ    5642
# SC    5601
# OH    5601
# IN    5601
# TX    5601
# CA    5601
# ID    5601
# NV    5601
# PR    4166
# VI    3969
# GU    3969
# Name: count, dtype: int64
# **********
# LocationDesc
# United States           5763
# Tennessee               5750
# Alabama                 5748
# Vermont                 5748
# Pennsylvania            5748
# Utah                    5748
# ...

# %%
df.describe()
# Out:
#        YearStart   YearEnd  DataValue  DataValueAlt  LowConfidenceLimit  \
# count  309215.00 309215.00  209196.00     209196.00           188885.00
# mean     2020.01   2020.29     694.36        735.67               36.83
# std         1.53      1.07   16203.41      18347.15               65.03
# min      2015.00   2019.00       0.00          0.00                0.00
# 25%      2019.00   2019.00      12.40         12.40                9.10
# 50%      2020.00   2020.00      27.00         27.00               19.50
# 75%      2021.00   2021.00      57.80         57.80               40.30
# max      2022.00   2022.00 2925456.00    2925456.00             1427.00
#
#        HighConfidenceLimit  LocationID
# count            188890.00   309215.00
# mean                 46.03       31.21
# std                  70.00       17.80
# min                   0.00        1.00
# 25%                  14.00       17.00
# 50%                  29.20       31.00
# 75%                  54.30       45.00
# ...

# %%
df.describe().T
# Out:
#                         count    mean      std     min     25%     50%  \
# YearStart           309215.00 2020.01     1.53 2015.00 2019.00 2020.00
# YearEnd             309215.00 2020.29     1.07 2019.00 2019.00 2020.00
# DataValue           209196.00  694.36 16203.41    0.00   12.40   27.00
# DataValueAlt        209196.00  735.67 18347.15    0.00   12.40   27.00
# LowConfidenceLimit  188885.00   36.83    65.03    0.00    9.10   19.50
# HighConfidenceLimit 188890.00   46.03    70.00    0.00   14.00   29.20
# LocationID          309215.00   31.21    17.80    1.00   17.00   31.00
#
#                         75%        max
# YearStart           2021.00    2022.00
# YearEnd             2021.00    2022.00
# DataValue             57.80 2925456.00
# DataValueAlt          57.80 2925456.00
# LowConfidenceLimit    40.30    1427.00
# HighConfidenceLimit   54.30    1485.90
# LocationID            45.00      78.00

# %%
df.describe(include="object")
# Out:
#        LocationAbbr   LocationDesc DataSource                   Topic  \
# count        309215         309215     309215                  309215
# unique           55             55         14                      19
# top              US  United States      BRFSS  Cardiovascular Disease
# freq           5763           5763     195594                   30709
#
#                                                  Question DataValueUnit  \
# count                                              309215        309215
# unique                                                109             8
# top     Binge drinking frequency among adults who bing...             %
# freq                                                 5720        203382
#
#            DataValueType StratificationCategory1 Stratification1  \
# count             309215                  309215          309215
# unique                12                       5              26
# ...

# %%
for i in df.select_dtypes(include="number").columns: 
    sns.histplot(data=df, x=i) 
    plt.show()

# %%
print(df.isnull().sum())
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# DataSource                        0
# Topic                             0
# Question                          0
# Response                     309215
# DataValueUnit                     0
# DataValueType                     0
# DataValue                    100019
# DataValueAlt                 100019
# DataValueFootnoteSymbol      207499
# DataValueFootnote            207499
# LowConfidenceLimit           120330
# HighConfidenceLimit          120325
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2      309215
# Stratification2              309215
# StratificationCategory3      309215
# Stratification3              309215
# Geolocation                    5763
# LocationID                        0
# TopicID                           0
# QuestionID                        0
# ...

# %%
import pandas as pd

df = pd.read_csv("U.S._Chronic_Disease_Indicators.csv")  # Replace with your actual file
print(df.head())
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource     Topic  \
# 0       2019     2019           AR     Arkansas      BRFSS  Diabetes
# 1       2019     2019           ID        Idaho      BRFSS  Diabetes
# 2       2019     2019           IN      Indiana      YRBSS     Sleep
# 3       2019     2019           IA         Iowa       NVSS    Asthma
# 4       2019     2019           IA         Iowa      BRFSS    Asthma
#
#                                             Question  Response DataValueUnit  \
# 0                              Diabetes among adults       NaN             %
# 1                              Diabetes among adults       NaN             %
# 2    Short sleep duration among high school students       NaN             %
# 3  Asthma mortality among all people, underlying ...       NaN        Number
# 4                        Current asthma among adults       NaN             %
#
#       DataValueType  ...  TopicID  QuestionID ResponseID DataValueTypeID  \
# ...

# %%
# !git --version
# Out:
# git version 2.39.5 (Apple Git-154)

# %%
git status
# Out:
#   Cell In[3], line 1
#     git status
#         ^
# SyntaxError: invalid syntax
